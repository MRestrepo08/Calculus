# %% [markdown]
# <a href="https://colab.research.google.com/github/MRestrepo08/Calculus/blob/main/Graphics2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy import symbols
from sympy.plotting import plot3d
x, y, z = symbols('x y z')

# %%
plot3d(x**2+y**2, (x, -5, 5), (y, -5, 5))
